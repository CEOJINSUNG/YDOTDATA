# %%
import pandas as pd

ranking = pd.read_csv("ranking.csv")
social = pd.read_csv("social.csv")

# %%
ranking.head()
ranking.drop("Unnamed: 0", inplace=True, axis=1)
social.drop("Unnamed: 0", inplace=True, axis=1)

# %%
social.head()
# Out:
#                           name         sub  genre
# 0                    BLACKPINK  53,100,000  음악/댄스
# 1               Big Hit Labels  46,700,000  음악/댄스
# 2                    BANGTANTV  40,200,000  음악/댄스
# 3  Boram Tube Vlog [보람튜브 브이로그]  27,000,000     키즈
# 4       Baby Doli - ToyPudding  25,500,000     취미

# %%
len(social)
# Out:
# 3716

# %%
int(social.iloc[0]['sub'].replace(',', ''))
# Out:
# 53100000

# %%
print(social.iloc[3256])
# Out:
# name     미디어자몽 ZMTV
# sub           1,000
# genre      뉴스/정치/이슈
# Name: 3256, dtype: object

# %%
notten = []
for i in range(0, 3257):
    notten.append(social.iloc[i])

dd = pd.DataFrame(notten)
print(dd)
# Out:
#                                      name         sub     genre
# 0                               BLACKPINK  53,100,000     음악/댄스
# 1                          Big Hit Labels  46,700,000     음악/댄스
# 2                               BANGTANTV  40,200,000     음악/댄스
# 3             Boram Tube Vlog [보람튜브 브이로그]  27,000,000        키즈
# 4                  Baby Doli - ToyPudding  25,500,000        취미
# ...                                   ...         ...       ...
# 3252                      나무노트 namoo note       1,020   여행/아웃도어
# 3253                                  토미스       1,010     푸드/쿠킹
# 3254                              어른이의 하루       1,010        게임
# 3255  A L E X 「No.1 Asian men’s ambition」       1,010     교육/강의
# 3256                           미디어자몽 ZMTV       1,000  뉴스/정치/이슈
#
# [3257 rows x 3 columns]

# %%
ranking.head()
# Out:
#                           name    sub       genre
# 0                    BLACKPINK  5300만  [음악/댄스/가수]
# 1               Big Hit Labels  4660만  [음악/댄스/가수]
# 2                    BANGTANTV  4010만  [음악/댄스/가수]
# 3  Boram Tube Vlog [보람튜브 브이로그]  2650만  [음악/댄스/가수]
# 4                       SMTOWN  2480만  [음악/댄스/가수]

# %%
ranking.iloc[4897]
# Out:
# name           난캔트래블
# sub             1000
# genre    [음식/요리/레시피]
# Name: 4897, dtype: object

# %%
noten = []
for i in range(0, 4898):
    noten.append(ranking.iloc[i])

ee = pd.DataFrame(noten)
print(ee)
# Out:
#                                      name    sub        genre
# 0                               BLACKPINK  5300만   [음악/댄스/가수]
# 1                          Big Hit Labels  4660만   [음악/댄스/가수]
# 2                               BANGTANTV  4010만   [음악/댄스/가수]
# 3             Boram Tube Vlog [보람튜브 브이로그]  2650만   [음악/댄스/가수]
# 4                                  SMTOWN  2480만   [음악/댄스/가수]
# ...                                   ...    ...          ...
# 4893                              어른이의 하루   1020  [음식/요리/레시피]
# 4894                                  토미스   1020  [음식/요리/레시피]
# 4895  A L E X 「No.1 Asian men’s ambition」   1010  [음식/요리/레시피]
# 4896                           미디어자몽 ZMTV   1010  [음식/요리/레시피]
# 4897                                난캔트래블   1000  [음식/요리/레시피]
#
# [4898 rows x 3 columns]

# %%
dd['name']
# Out:
# 0                                 BLACKPINK
# 1                            Big Hit Labels
# 2                                 BANGTANTV
# 3               Boram Tube Vlog [보람튜브 브이로그]
# 4                    Baby Doli - ToyPudding
#                        ...
# 3252                        나무노트 namoo note
# 3253                                    토미스
# 3254                                어른이의 하루
# 3255    A L E X 「No.1 Asian men’s ambition」
# 3256                             미디어자몽 ZMTV
# Name: name, Length: 3257, dtype: object

# %%
ee['name']
# Out:
# 0                                 BLACKPINK
# 1                            Big Hit Labels
# 2                                 BANGTANTV
# 3               Boram Tube Vlog [보람튜브 브이로그]
# 4                                    SMTOWN
#                        ...
# 4893                                어른이의 하루
# 4894                                    토미스
# 4895    A L E X 「No.1 Asian men’s ambition」
# 4896                             미디어자몽 ZMTV
# 4897                                  난캔트래블
# Name: name, Length: 4898, dtype: object

# %%
dd['name'][0]
# Out:
# 'BLACKPINK'

# %%
ee['name'][0]
# Out:
# 'BLACKPINK'

# %%
name = []
for i in dd['name']:
    for j in ee['name']:
        if (i==j):
            name.append(j)
print(name)
# Out:
# ['BLACKPINK', 'Big Hit Labels', 'BANGTANTV', 'Boram Tube Vlog [보람튜브 브이로그]', 'SMTOWN', '1MILLION Dance Studio', '1theK (원더케이)', 'JYP Entertainment', 'JFlaMusic', 'Mnet K-POP', 'Jane ASMR 제인', 'DuDuPopTOY', 'Stone Music Entertainment', 'TWICE', '핑크퐁 (인기 동요・동화)', 'Larva TUBA', 'Toymong tv 토이몽TV', '서은이야기[SeoeunStory]', 'Mnet Official', 'MariAndKids', 'Boram Tube [宝蓝和朋友们]', 'SonicToy소닉토이', 'Sungha Jung', 'EXO', 'M2', 'Hongyu ASMR 홍유', 'ALL THE K-POP', 'SEVENTEEN', 'YG ENTERTAINMENT', 'PONY Syndrome', 'GOT7', 'TOMORROW X TOGETHER OFFICIAL', '콩순이・시크릿 쥬쥬 [Kongsuni・Secret Jouju]', '2NE1', 'Samsung', 'ToyMart TV', 'MAMAMOO', '[Awesome Haeun]어썸하은', '문복희 Eat with Boki', '[햄지]Hamzy', "백종원의 요리비책 Paik's Cuisine", 'starshipTV', '베이비버스 -인기 동요・동화', '스위트티비 SweetTV', '떵개떵', '미니특공대TV', '뽀로로(Pororo)', '[Dorothy]도로시', 'Evan Kids', 'Raon Lee', '영국남자 Korean Englishman', 'BT21', '하루한끼 one meal a day', 'Jaeguchi', '크림히어로즈', '워크맨-Workman', '허팝Heopop', 'waveya 2011', 'JTBC Drama', 'Cooking tree 쿠킹트리', 'SBS TV동물농
# ...

# %%
len(name)
# Out:
# 2544

# %%
a = set(dd['name'])
print(a)
# Out:
# {'Kai Ruiz', '테크몽 Techmong', 'BANGTANTV', '민생TV', '알트 ALT', '쁘허', '쩡유 JJeong U', '임용수의토크백', '고니드럼', '라피', '순위충', '남순 NS', '방프로 채널', 'Larva TUBA', 'haha ha', 'PAUL LAND폴랜드', '충청북도', '녹밥', '해물파전TV', 'Lemondrizzle', '승끼', '제이제이', '이녕', '무소과금TV', 'DinoBattle TteokooTV', '육식맨 YOOXICMAN', 'DIOD BEAUTY', '동원F&B', '밴쯔 클래식', '하얀손 White hand', '무결의 VR게임', '코이티비KOITV', '주식단테tv-작전주,경제차트분석전문 채널', '메이슨미드영어회화', '김명연TV', '단비스 Toy', 'smile -wA-', '소피루비 - SofyRuby Official', '말왕TV', '오승민 세금교육연구소', 'KBS더라이브', "황꿀 gguul's boundary", 'Purple Pot-퍼플팟', 'dViNC3b', '서울리안 SEOULiAN', '슈떡', '에바EVA', 'Ranking World', '티웨이항공', 'kiu기우쌤', 'VIVO TV - 비보티비', '와조스키', "빠꿈's Mobile Game", 'dodo도도', '김동길TV', 'SONA TV', '맘톡지민언니', '돌아온 꽃총TV', '굴즈야밥묵자', '푸니', 'M2', "화니 HWAN'E", '느피', '알짜 Rzza', '청정원', '재미어트', '권와코 Wackogwon', '채보미[BOMITUBE]', '무비희락 MovieJOY', '자몽푸드 ZAMONG Food', 'TV모자람', '소희짱', 'hanabono하나보노', "네일하는 샨언니SHYAN's Nail", '기즈모 gizmo', '경기도교육청TV', 'heekkong희꽁', '0zoo 영주', 'ARIKITCHEN (아리키친)', 'MapleStory_KR', '여
# ...

# %%
diff = list(a - set(name))
len(diff)
# Out:
# 716

# %%
b = set(ee['name'])
diff2 = list(b - set(name))
len(diff2)
# Out:
# 2335

# %%
total = list(set(name) | set(diff) | set(diff2))
len(total)
# Out:
# 5591

# %%
total
# Out:
# ['Kai Ruiz',
#  '테크몽 Techmong',
#  'BANGTANTV',
#  '민생TV',
#  '정치초단',
#  '알트 ALT',
#  '쁘허',
#  'MBC경남 Entertain',
#  'LOUD CAST',
#  '쩡유 JJeong U',
#  'KBS창원 뮤직',
#  'Chuther츄더[문에스더]',
#  '고니드럼',
#  "히피스 토이즈 Hippie's Toys",
#  '순위충',
#  '방프로 채널',
#  'Larva TUBA',
#  '녹밥',
#  '해물파전TV',
#  '유미유미TV',
#  '이녕',
#  "킴스트래블 Kim's Travel",
#  '무소과금TV',
#  '룰루랄라 스토리랩- Lululala Story Lab',
#  'DinoBattle TteokooTV',
#  '육식맨 YOOXICMAN',
#  '[양한성] 이지골프양프로TV',
#  '밴쯔 클래식',
#  '무결의 VR게임',
#  '주식단테tv-작전주,경제차트분석전문 채널',
#  '메이슨미드영어회화',
#  '단비스 Toy',
#  '네오아카데미',
#  '몬구골프',
#  'smile -wA-',
#  'Roy Kim - Topic',
#  'Olive',
#  '말왕TV',
#  '왓섭! 공포라디오',
#  '오승민 세금교육연구소',
#  '연합뉴스 Yonhapnews',
#  '남도여행길잡이 Jeollanamdo, Korea',
#  'KBS더라이브',
#  'BerryTV',
#  'honjayori혼자요',
#  'Purple Pot-퍼플팟',
#  '최혜영골프 choigolf',
#  '이제이군',
#  'dViNC3b',
#  '서울리안 SEOULiAN',
#  '슈떡',
#  '이환',
#  'Ranking World',
#  '티웨이항공',
#  '또봇 V · 메탈리온 [Tobot V · Metalions]',
#  '무나홈트 Moona Workout',
#  "빠꿈's Mobile Game",
#  'dodo도도',
# ...

# %%
total.remove("제이콩 아빠되기 How to Dad for JCONG")

# %%
from IPython.display import Image

# %%
Image("Y.DB.png")

# %% [markdown]
# ### 데이터 API
# 1. guideCategory : https://www.googleapis.com/youtube/v3/guideCategories
# 2. channels : https://www.googleapis.com/youtube/v3/channels

# %% [markdown]
# ### 수집방법
# 1. 크롤링
# 2. youtube data api 활용 <- 이거 활용하기로 함
# 3. youtube analytics api 활용

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

# %%
DEVELOPER_KEY = "AIzaSyA6bn5e0IG5FkUp1i1PcnKRVPJcGWLFOUs"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# %%
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)

# %%
sub = youtube.search().list(
    q = "롤린 거울모드",
    part = "snippet",
    maxResults = 10,
    regionCode = "KR",
    type="video"
).execute()

print(sub)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'PAN9jRYdIGfSCT4ru071isVhcDs', 'nextPageToken': 'CAoQAA', 'regionCode': 'KR', 'pageInfo': {'totalResults': 129997, 'resultsPerPage': 10}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'MYaLObg6jYqbskqVDyE5ELticZo', 'id': {'kind': 'youtube#video', 'videoId': 'TDnACUpGnqs'}, 'snippet': {'publishedAt': '2021-03-21T04:30:01Z', 'channelId': 'UCFVo3W5Vy_EGCcj3bbhcEWQ', 'title': '브레이브걸스 Brave Girls - 롤린 (Rollin&#39;) | 커버댄스 DANCE COVER | 안무 거울모드 MIRROR MODE (2021 VER.)', 'description': '☑️ Dancer (@Instagram) : 은비 EunBi (IG: @choevbi) 유림 YuRim (IG: @yurim__m_) 현아 HyunA (IG: @hyuna___m) 유정 YuJung (IG: @1004leeyj) ☑️ 의상 ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TDnACUpGnqs/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/TDnACUpGnqs/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/TDnACUpGnqs/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelT
# ...

# %%
sub["items"]
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': 'trI2Iwv6NqwU683XuMItcElMRUk',
#   'id': {'kind': 'youtube#channel', 'channelId': 'UC9ZLv1m7QDLv991X1-p50AA'},
#   'snippet': {'publishedAt': '2012-11-14T13:37:53Z',
#    'channelId': 'UC9ZLv1m7QDLv991X1-p50AA',
#    'title': '보물섬',
#    'description': '아룡하세요~~ 허잇     매번 다양하고 새로운 웃음을 시도하는 삼인조 유머 크리에이터 보물섬  입니다   Hellow~~ huh it     We are three-member humor creator ...',
#    'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngDVK35W9bF1r69ZX_hwPr116__bkxlmBNRJK2F=s88-c-k-c0xffffffff-no-rj-mo'},
#     'medium': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngDVK35W9bF1r69ZX_hwPr116__bkxlmBNRJK2F=s240-c-k-c0xffffffff-no-rj-mo'},
#     'high': {'url': 'https://yt3.ggpht.com/ytc/AAUvwngDVK35W9bF1r69ZX_hwPr116__bkxlmBNRJK2F=s800-c-k-c0xffffffff-no-rj-mo'}},
#    'channelTitle': '보물섬',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2012-11-14T13:37:53Z'}},
#  {'kind': 'youtube#searchResult',
# ...

# %%
import requests, json
videoUrl = "https://www.googleapis.com/youtube/v3/videos"
params={"part": "statistics", "id": "TDnACUpGnqs", "key" : DEVELOPER_KEY}
res = requests.get(videoUrl, params=params)
snippet = res.json()
snippet
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'A_dnDLZqFw_7nqCbSCv8LgfpC5U',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'BAFt4CVvHXuq1EY4oVjlAx1XB8Y',
#    'id': 'TDnACUpGnqs',
#    'statistics': {'viewCount': '823396',
#     'likeCount': '12468',
#     'dislikeCount': '221',
#     'favoriteCount': '0',
#     'commentCount': '510'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
import requests, json
channelUrl = "https://www.googleapis.com/youtube/v3/channels"
params={'part': 'snippet', 'id' : "UCFVo3W5Vy_EGCcj3bbhcEWQ", 'key' : DEVELOPER_KEY}
res = requests.get(channelUrl, params=params)
snippet = res.json()
snippet['items'][0]['snippet']["thumbnails"]["default"]["url"]
# Out:
# 'https://yt3.ggpht.com/ytc/AAUvwnhB2WhNZfzpPTqd8TvUAC7MbKVgpcO0J7u9CqSqmA=s88-c-k-c0x00ffffff-no-rj'

# %%
channelUrl = "https://www.googleapis.com/youtube/v3/channels"
params={'part': 'statistics', 'id' : ChannelId, 'key' : DEVELOPER_KEY}
res = requests.get(channelUrl, params=params)
statistics = res.json()
statistics['items'][0]['statistics']
# Out:
# {'viewCount': '885938234',
#  'subscriberCount': '1720000',
#  'hiddenSubscriberCount': False,
#  'videoCount': '371'}

# %%
channelUrl = "https://www.googleapis.com/youtube/v3/channels"
params={'part': 'topicDetails', 'id' : ChannelId, 'key' : DEVELOPER_KEY}
res = requests.get(channelUrl, params=params)
topicDetails = res.json()
len(topicDetails['items'][0]['topicDetails']['topicCategories'])
# Out:
# 2

# %%
i = 1

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser
import pandas as pd
import requests, json
import datetime

# 개발자 키
DEVELOPER_KEY = "AIzaSyBw5WOxx5--3FKXCByemUDm_1yLFxNKCsY"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)
channelUrl = "https://www.googleapis.com/youtube/v3/channels"

# 데이터 갱신 날
getDate = datetime.datetime.now().strftime('%Y-%m-%d')

# 고유의 ChannelId 찾기
def searchChannelId(name):
    sub = youtube.search().list(
        q = name,
        part = "snippet",
        maxResults = 10,
        regionCode = "KR",
        type="channel"
    ).execute()
    
    dic = sub['items']
    ChannelId = dic[0]['snippet']['channelId']
    return ChannelId

# ChannelId를 활용해 Channel Snippet 사용
def findSnippet(url, channelid):
    params={'part': 'snippet', 'id' : channelid, 'key' : DEVELOPER_KEY}
    res = requests.get(url, params=params)
    snippet = res.json()
    return snippet['items'][0]['snippet']

# ChannelId를 활용해 Channel Statistics 사용
def findStatistics(url, channelid):
    params={'part': 'statistics', 'id' : channelid, 'key' : DEVELOPER_KEY}
    res = requests.get(url, params=params)
    statistics = res.json()
    return statistics['items'][0]['statistics']

# ChannelId를 활용해 Channel topicDetails 사용
def findtopicDetails(url, channelid):
    params={'part': 'topicDetails', 'id' : channelid, 'key' : DEVELOPER_KEY}
    res = requests.get(url, params=params)
    topicDetails = res.json()
    if ('topicDetails' in topicDetails['items'][0]): 
        if ('topicCategories' in topicDetails['items'][0]['topicDetails']):
            return topicDetails['items'][0]['topicDetails']['topicCategories']
        else: return "미분류"
    else: return "미분류"

def firstChannel(url, name):
    originId = searchChannelId(name)
    snippet = findSnippet(channelUrl, originId)
    statistics = findStatistics(channelUrl, originId)
    topicDetails = findtopicDetails(channelUrl, originId)
    if (statistics['hiddenSubscriberCount'] == True):
        return pd.Series([])
    YoutuberInfo = {
        'GetTime' : getDate,
        'ChannelId' : originId, 
        'ChannelTitle' : name, 
        'ChannelKind' : topicDetails,
        'ChannelRegion' : "KR",
        'ChannelLogoD' : snippet['thumbnails']['default']['url'], 
        'ChannelLogoM' : snippet['thumbnails']['medium']['url'], 
        'ChannelLogoH' : snippet['thumbnails']['high']['url'], 
        'ChannelDescription' : snippet['description'],
        'ChannelSubscriberCount' : statistics['subscriberCount'],
        'ChannelViewCount' : statistics['viewCount'],
        'ChannelVideoCount' : statistics['videoCount'],
        'ChannelPublishedAt' : snippet['publishedAt']
    }
    data = pd.DataFrame.from_records([YoutuberInfo])
    return data

# %%
print(i)
# Out:
# 1

# %%
my_youtube = pd.DataFrame(data = [[
                                   'GetTime',
                                   'ChannelId', 
                                   'ChannelTitle', 
                                   'ChannelKind', 
                                   'ChannelRegion', 
                                   'ChannelLogoD',
                                   'ChannelLogoM',
                                   'ChannelLogoH',
                                   'ChannelDescription',
                                   'ChannelSubscriberCount',
                                   'ChannelViewCount',
                                   'ChannelVideoCount',
                                   'ChannelPublishedAt'
                               ]], columns = [
                                   'GetTime',
                                   'ChannelId', 
                                   'ChannelTitle', 
                                   'ChannelKind', 
                                   'ChannelRegion', 
                                   'ChannelLogoD',
                                   'ChannelLogoM',
                                   'ChannelLogoH',
                                   'ChannelDescription',
                                   'ChannelSubscriberCount',
                                   'ChannelViewCount',
                                   'ChannelVideoCount',
                                   'ChannelPublishedAt'
                               ])
my_youtube
# Out:
#    GetTime  ChannelId  ChannelTitle  ChannelKind  ChannelRegion  ChannelLogoD  \
# 0  GetTime  ChannelId  ChannelTitle  ChannelKind  ChannelRegion  ChannelLogoD
#
#    ChannelLogoM  ChannelLogoH  ChannelDescription  ChannelSubscriberCount  \
# 0  ChannelLogoM  ChannelLogoH  ChannelDescription  ChannelSubscriberCount
#
#    ChannelViewCount  ChannelVideoCount  ChannelPublishedAt
# 0  ChannelViewCount  ChannelVideoCount  ChannelPublishedAt

# %%
other_youtube = pd.DataFrame(data = [[
                                   'GetTime',
                                   'ChannelId', 
                                   'ChannelTitle', 
                                   'ChannelKind', 
                                   'ChannelRegion', 
                                   'ChannelLogoD',
                                   'ChannelLogoM',
                                   'ChannelLogoH',
                                   'ChannelDescription',
                                   'ChannelSubscriberCount',
                                   'ChannelViewCount',
                                   'ChannelVideoCount',
                                   'ChannelPublishedAt'
                               ]], columns = [
                                   'GetTime',
                                   'ChannelId', 
                                   'ChannelTitle', 
                                   'ChannelKind', 
                                   'ChannelRegion', 
                                   'ChannelLogoD',
                                   'ChannelLogoM',
                                   'ChannelLogoH',
                                   'ChannelDescription',
                                   'ChannelSubscriberCount',
                                   'ChannelViewCount',
                                   'ChannelVideoCount',
                                   'ChannelPublishedAt'
                               ])
other_youtube
# Out:
#    GetTime  ChannelId  ChannelTitle  ChannelKind  ChannelRegion  ChannelLogoD  \
# 0  GetTime  ChannelId  ChannelTitle  ChannelKind  ChannelRegion  ChannelLogoD
#
#    ChannelLogoM  ChannelLogoH  ChannelDescription  ChannelSubscriberCount  \
# 0  ChannelLogoM  ChannelLogoH  ChannelDescription  ChannelSubscriberCount
#
#    ChannelViewCount  ChannelVideoCount  ChannelPublishedAt
# 0  ChannelViewCount  ChannelVideoCount  ChannelPublishedAt

# %%
total[16]
# Out:
# '오씨네학교'

# %%
total.index("박정윤의_멍냥멍냥")
# Out:
# 44

# %%
total[45]
# Out:
# '채널 좀비왕'

# %%
for name in total[45:]:
    a = firstChannel(channelUrl, name)
    print(name)
    if (a.empty == True):
        continue
    other_youtube = pd.concat([other_youtube, a])
other_youtube
# Out:
# 채널 좀비왕
# 플라톤아카데미TV
# Giants TV
# EXBC entertainment
# 키키 - KiKi Surprise
# 최빛빛
# 붇옹산TV
# 히조이 heejoyee
# 김갈릭 KimGarlic
# 에프람
# 파이월드TV [PiworldTV]
# 모터피디
# 박라인 TV
# sobong official
# 마틴의 Market of Art
# 줌인센타 zoom in centre
# 사랑아놀자(Let's Play SARANG)
# Team_SeikaTV(팀세이카)
# Apink - Topic
# 유이뿅YUIPYON
# [직캠/FANCAM]수원촌놈
# DOJIN도진이
# BapMokja and Haeppy
# EBSDocumentary (EBS 다큐)
# 대형견가족
# 리프팅스쿼드
# 삼둥이네TV
# OfficialGDRAGON
# 맨투맨중고차
# 리재영
# 맘톡지민언니
# 우주하마
# 진호
# MBC PD수첩
# 이정미TV
# KoreanJulie 코리안줄리
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-104-606cc9d8ff94> in <module>
#       1 for name in total[45:]:
# ----> 2     a = firstChannel(channelUrl, name)
#       3     print(name)
#       4     if (a.empty == True):
#       5         continue
#
# <ipython-input-103-a34d48f1b692> in firstChannel(url, name)
#      56
#      57 def firstChannel(url, name):
# ...

# %%
other_youtube
# Out:
#        GetTime                 ChannelId             ChannelTitle  \
# 0      GetTime                 ChannelId             ChannelTitle
# 0   2020-12-02  UCQh2Y_YruflVVzzP85Q-Y_g  저니맨 용이 Journeyman YongE
# 0   2020-12-02  UCMrf2b4mZYxH9uZW2rZReyg                    오씨네학교
# 0   2020-12-02  UC8jn6wsEWH9Edynop6DYX8g                      구라철
# 0   2020-12-02  UCx_dzPI6efSohgtOkAG43-A                   EBS 키즈
# ..         ...                       ...                      ...
# 0   2020-12-02  UC2NFRq9s2neD_Ml0tPhNC2Q                     우주하마
# 0   2020-12-02  UCXZaTqDKXHmNfKZ1ywhxe0w                       진호
# 0   2020-12-02  UCawCv9kO2UXbTtsK4EammRQ                 MBC PD수첩
# 0   2020-12-02  UCjt2kiS1N_6NE2I0sWywNoA                    이정미TV
# 0   2020-12-02  UCWvolJs14-6DMqa3fFypW0A        KoreanJulie 코리안줄리
#
#                                           ChannelKind  ChannelRegion  \
# 0                                         ChannelKind  ChannelRegion
# ...

# %%
my_youtube
# Out:
#       GetTime                 ChannelId             ChannelTitle  \
# 0     GetTime                 ChannelId             ChannelTitle
# 1  2020-12-02  UCuNf3-4O7n8S50c7F7wjosw                      유`s
# 1  2020-12-02  UC8WoHUeN-eLynnLKGkwajYQ         Beginagain 비긴어게인
# 1  2020-12-02  UCgD39GkKBeD2oafFAE41GmQ        파우더룸& POWDERROOM&
# 1  2020-12-02  UCQ_iJkuEJFStr2r4eeq-tHA                   atooTV
# 1  2020-12-02  UCl9nsRuGenStMDZfD95w85A                BLACKHAND
# 1  2020-12-02  UCBHNpZdf3he6kvzyescOBAQ                ONSTYLE D
# 1  2020-12-02  UC3vlU5ziv8njjin3iq-86Kw                   간이과세주하
# 1  2020-12-02  UCmONdwaYe2AWLSG_NYF9RhA                   STAR K
# 1  2020-12-02  UCB3BKKiUtMYuPoagCSTyn1Q                   삼성서울병원
# 1  2020-12-02  UCRJX0GaKcnMO4L2EttYqPaQ                 로미쌤 ROMI
# 1  2020-12-02  UCJDDUcBtJYT1yRX9pR4Q0ug          Aejeong ASMR 애정
# 1  2020-12-02  UCAo41QETLlwvJ-oqjmEPt8A                  joanday
# ...

# %%
firstChannel(channelUrl, "크림히어로즈")

# %%
import datetime
now = datetime.datetime.now()
print(now)      

nowDate = now.strftime('%Y-%m-%d')
print(str(nowDate)) 
 
nowTime = now.strftime('%H:%M:%S')
print(nowTime)    
 
nowDatetime = now.strftime('%Y-%m-%d %H:%M:%S')
print(nowDatetime)

# %%
a = searchChannelId("더블비")
b = findSnippet(channelUrl, a)
c = findStatistics(channelUrl, a)
d = findtopicDetails(channelUrl, a)
dicts = {
    'GetTime' : nowDate,
    'ChannelId' : a, 
    'ChannelTitle' : "더블비", 
    'ChannelKind' : d,
    'ChannelRegion' : "KR",
    'ChannelLogoD' : b['thumbnails']['default']['url'], 
    'ChannelLogoM' : b['thumbnails']['medium']['url'], 
    'ChannelLogoH' : b['thumbnails']['high']['url'], 
    'ChannelDescription' : b['description'],
    'ChannelSubscriberCount' : c['subscriberCount'],
    'ChannelViewCount' : c['viewCount'],
    'ChannelVideoCount' : c['videoCount'],
    'ChannelPublishedAt' : b['publishedAt']
}

k = pd.DataFrame(dicts, columns = [
                               'GetTime',
                               'ChannelId', 
                               'ChannelTitle', 
                               'ChannelKind', 
                               'ChannelRegion', 
                               'ChannelLogoD',
                               'ChannelLogoM',
                               'ChannelLogoH',
                               'ChannelDescription',
                               'ChannelSubscriberCount',
                               'ChannelViewCount',
                               'ChannelVideoCount',
                               'ChannelPublishedAt'
                           ], index = [0])
k

# %%
a = searchChannelId("더블비")
b = findSnippet(channelUrl, a)
c = findStatistics(channelUrl, a)
d = findtopicDetails(channelUrl, a)
dict = [
    a, 
    "더블비", 
    d,
    "KR",
    b['thumbnails'], 
    b['description'],
    c['subscriberCount'],
    c['viewCount'],
    c['videoCount'],
    b['publishedAt']
]

k = pd.DataFrame(dict)
print(k)
